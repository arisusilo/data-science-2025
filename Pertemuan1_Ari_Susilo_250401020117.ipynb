# %% [markdown]
# <a href="https://colab.research.google.com/github/arisusilo/data-science-2025/blob/main/Pertemuan1_Ari_Susilo_250401020117.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# SEL 1: Output sederhana
print("Hello, Data Sciencel!")

# SEL 2: Variabel & tipe data
nama     = "Ari Susilo"
angkatan = 2026
print(f"Halo, {nama} angkatan {angkatan}!")

# SEL 3: List & perulangan
tools = ["Python","Colab","Jupyter","GitHub"]
for i, tool in enumerate(tools, 1):
  print(f"  {i}. {tool}")

# SEL 4: Fungsi Python
def perkenalan(nama, prodi, angkatan):
  return f"{nama} | {prodi} | {angkatan}"
print(perkenalan("Ari","Informatika",2026))
# Out:
# Hello, Data Sciencel!
# Halo, Ari Susilo angkatan 2026!
#   1. Python
#   2. Colab
#   3. Jupyter
#   4. GitHub
# Ari | Informatika | 2026
